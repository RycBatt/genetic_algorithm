# %%
from ga import GeneticAlgorithm as GA
from agents import Agent
import numpy
from matplotlib import pyplot as plt


alfabeto = " abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!.,"
in_str = None
in_str_len = None
populacao = 50
geracoes = 1000

# %%
## Plotagem
def bar_plot(ax, data, colors=None, total_width=0.8, single_width=1, legend=True):
    if colors is None:
        colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
    n_bars = len(data)
    bar_width = total_width / n_bars
    bars = []
    for i, (name, values) in enumerate(data.items()):
        x_offset = (i - n_bars / 2) * bar_width + bar_width / 2
        for x, y in enumerate(values):
            bar = ax.bar(x + x_offset, y, width=bar_width * single_width, color=colors[i % len(colors)])
        bars.append(bar[0])
    if legend:
        ax.legend(bars, data.keys())

# %%
## Principal

if __name__ == '__main__':
    
    frases = {
      "AI is changing the game",
      "Smart machines shape AI",
      "AI leads the way forward",
      "Data empowers AI systems",
      "Machine learning drives AI",
      "AI unlocks new potential",
      "AI transforms industries",
      "Ethics guide responsible AI",
      "AI fuels technological progress",
      "AI revolutionizes our world",
    }

    final = {
        "E1" : numpy.zeros(10),
        "E2" : numpy.zeros(10),
    }
    phase_result = []
    index = 0
    for frase in frases:
      in_str = frase
      in_str_len = len(in_str)
      results = {
        "E1" : numpy.zeros(10),
        "E2" : numpy.zeros(10),
      }
      print(frase)

      mutation_max = 1.0
      selection_max = 1.0
      split_max = in_str_len

      mutation_lst = []
      selection_lst = []  

      for mutation in numpy.arange(0.1, mutation_max, (mutation_max-0.1)/2):
        mutation_lst.append(mutation)
        for selection in numpy.arange(0.1, selection_max, (selection_max-0.1)/2):
            results_lst = []
            print("Taxa de mutação: " + str(mutation) + " e taxa de seleçao " + str(selection))
            selection_lst.append(selection)
            ga1 = GA(alfabeto, populacao, geracoes, frase, mutation, selection)
            results_lst.append(numpy.mean(ga1.execute()))
            phase_result.append([frase, mutation, selection, results_lst])
# Out:
# Machine learning drives AI
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# AI transforms industries
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# AI fuels technological progress
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# AI revolutionizes our world
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# AI is changing the game
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# AI leads the way forward
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# AI unlocks new potential
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# Ethics guide responsible AI
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# Smart machines shape AI
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55
# Data empowers AI systems
# Taxa de mutação: 0.1 e taxa de seleçao 0.1
# Solução encontrada
# Taxa de mutação: 0.1 e taxa de seleçao 0.55
# Taxa de mutação: 0.55 e taxa de seleçao 0.1
# Taxa de mutação: 0.55 e taxa de seleçao 0.55

# %%
#iterate over result to get the best combination
best_results = [[]]
best_result = phase_result[0]
for frase in frases:
    for phase in phase_result:
        if phase[0] == frase:
            print(phase[3][0])
            if int(phase[3][0]) < int(best_result[3][0]):
                best_result = phase
    best_results.append(best_result)
# Out:
# 160.0
# 1000.0
# 1000.0
# 1000.0
# 145.0
# 1000.0
# 1000.0
# 1000.0
# 186.0
# 1000.0
# 1000.0
# 1000.0
# 90.0
# 1000.0
# 1000.0
# 1000.0
# 70.0
# 1000.0
# 1000.0
# 1000.0
# 113.0
# 1000.0
# 1000.0
# 1000.0
# 77.0
# 1000.0
# 1000.0
# 1000.0
# 157.0
# 1000.0
# 1000.0
# 1000.0
# 48.0
# 1000.0
# 1000.0
# 1000.0
# 92.0
# 1000.0
# 1000.0
# 1000.0

# %%
print(best_results)
# Out:
# [[], ['Machine learning drives AI', 0.55, 0.55, [1000.0]], ['AI transforms industries', 0.55, 0.55, [1000.0]], ['AI fuels technological progress', 0.55, 0.55, [1000.0]], ['AI revolutionizes our world', 0.55, 0.55, [1000.0]], ['AI is changing the game', 0.55, 0.55, [1000.0]], ['AI leads the way forward', 0.55, 0.55, [1000.0]], ['AI unlocks new potential', 0.55, 0.55, [1000.0]], ['Ethics guide responsible AI', 0.55, 0.55, [1000.0]], ['Smart machines shape AI', 0.55, 0.55, [1000.0]], ['Data empowers AI systems', 0.55, 0.55, [1000.0]]]
